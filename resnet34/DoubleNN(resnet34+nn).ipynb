# %%
from google.colab import drive
drive.mount('/content/drive/')
import os
project_path = '/content/drive/MyDrive/Cornell/pvz'
os.chdir(project_path)
print("current path：", os.getcwd())
# Out:
# Mounted at /content/drive/
# current path： /content/drive/MyDrive/Cornell/pvz

# %%
import pickle
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from PIL import Image
from torch.utils.data import Dataset, DataLoader, random_split, Subset
from torchvision import transforms, models
import torchvision.transforms.functional as TF
from sklearn.model_selection import StratifiedKFold
import os
import time
import random
import torchvision.transforms.functional as TF

# %%
torch.manual_seed(42)
np.random.seed(42)
if torch.cuda.is_available():
  torch.cuda.manual_seed_all(42)
random.seed(42)

# %% [markdown]
# ## Configuration

# %%
# Data paths
TRAIN_PKL_PATH = 'train.pkl'
TEST_PKL_PATH = 'test.pkl'
SUBMISSION_CSV_PATH = 'submission_siamese_resnet_acc.csv'
MODEL_SAVE_PATH_TEMPLATE = 'best_siamese_resnet_fold_{fold}.pth'

# Hyperparameters
K_FOLDS = 5
BATCH_SIZE = 32
LEARNING_RATE = 1e-4
WEIGHT_DECAY = 1e-3
EPOCHS_PER_FOLD = 100

PATIENCE_LR = 3
PATIENCE_ES = 25
USE_PRETRAINED_BASE = True

# Inference Configuration
INFERENCE_BATCH_SIZE = 128

# Device
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {DEVICE}")
print(f"K-Fold Cross-Validation with K={K_FOLDS}")
# Out:
# Using device: cuda
# K-Fold Cross-Validation with K=5

# %% [markdown]
# ## Data Handling

# %%
class RPSSiameseDataset(Dataset):
    def __init__(self, pkl_path, transform=None):
        self.imgs1 = None
        self.imgs2 = None
        self.labels = None
        self.transform = transforms.Compose([
            transforms.RandomRotation(13),
            transforms.RandomHorizontalFlip(),
            transforms.RandomCrop(24, padding=2),
            transforms.RandomHorizontalFlip(p=0.5),
            transforms.ToTensor(),
            transforms.Normalize((0.5,), (0.5,))
            ])

        try:
            with open(pkl_path, 'rb') as f:
                data = pickle.load(f)
            print(f"Pickle file '{pkl_path}' loaded successfully.")

            print("Attempting to stack 'img1' data...")
            self.imgs1 = np.stack(data['img1']).astype(np.uint8) # Stack and ensure uint8 for PIL
            print(f"  'img1' stacked successfully. Shape: {self.imgs1.shape}")

            print("Attempting to stack 'img2' data...")
            self.imgs2 = np.stack(data['img2']).astype(np.uint8) # Stack and ensure uint8 for PIL
            print(f"  'img2' stacked successfully. Shape: {self.imgs2.shape}")

            labels_raw = np.array(data['label'])
            self.labels = torch.tensor((labels_raw == 1).astype(np.int64)) # 1 if img1 beats img2, else 0

            assert len(self.imgs1) == len(self.labels), "Mismatch between img1 count and labels count."
            assert len(self.imgs2) == len(self.labels), "Mismatch between img2 count and labels count."
            assert self.imgs1.shape[1:] == (24, 24), f"img1 shape error: {self.imgs1.shape}"
            assert self.imgs2.shape[1:] == (24, 24), f"img2 shape error: {self.imgs2.shape}"

            print(f"Dataset initialized successfully from {pkl_path}: {len(self.labels)} samples.")

        except FileNotFoundError:
            print(f"Error: File not found at {pkl_path}")
        except Exception as e:
            print(f"Error during dataset initialization from {pkl_path}: {e}")

            self.imgs1, self.imgs2, self.labels = None, None, None


    def __len__(self):
        return len(self.labels) if self.labels is not None else 0

    def __getitem__(self, idx):
        if self.imgs1 is None or self.imgs2 is None:
             raise IndexError("Dataset not initialized correctly.")

        im1_pil = Image.fromarray(self.imgs1[idx]) # Already uint8 from __init__
        im2_pil = Image.fromarray(self.imgs2[idx]) # Already uint8 from __init__
        y = self.labels[idx]

        # Apply independent transforms
        if self.transform:
            im1 = self.transform(im1_pil)
            im2 = self.transform(im2_pil)
        else:
            to_tensor = transforms.ToTensor()
            im1 = to_tensor(im1_pil)
            im2 = to_tensor(im2_pil)

        return im1, im2, y

# Dataset for Inference (Corrected Loading)
class RPSInferenceDataset(Dataset):
    def __init__(self, pkl_path, ids_key='id', img1_key='img1', img2_key='img2'):
        self.ids = None
        self.imgs1 = None
        self.imgs2 = None
        self.transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize((0.5,), (0.5,))
        ])

        try:
            with open(pkl_path, 'rb') as f:
                 data = pickle.load(f)
            print(f"Pickle file '{pkl_path}' loaded successfully for inference.")

            self.ids = data.get(ids_key)
            if self.ids is None:
                 raise ValueError(f"Key '{ids_key}' not found in pickle file.")
            self.ids = np.array(self.ids) # Ensure IDs are numpy array


            print("Attempting to stack 'img1' data for inference...")
            img1_data = data.get(img1_key)
            if img1_data is None: raise ValueError(f"Key '{img1_key}' not found.")
            self.imgs1 = np.stack(img1_data).astype(np.uint8)
            print(f"  'img1' stacked successfully. Shape: {self.imgs1.shape}")


            print("Attempting to stack 'img2' data for inference...")
            img2_data = data.get(img2_key)
            if img2_data is None: raise ValueError(f"Key '{img2_key}' not found.")
            self.imgs2 = np.stack(img2_data).astype(np.uint8)
            print(f"  'img2' stacked successfully. Shape: {self.imgs2.shape}")

            # Validation checks
            assert len(self.imgs1) == len(self.ids), "Mismatch between img1 count and ID count."
            assert len(self.imgs2) == len(self.ids), "Mismatch between img2 count and ID count."
            assert self.imgs1.shape[1:] == (24, 24), f"img1 shape error: {self.imgs1.shape}"
            assert self.imgs2.shape[1:] == (24, 24), f"img2 shape error: {self.imgs2.shape}"

            print(f"Inference dataset initialized successfully from {pkl_path}: {len(self.ids)} samples.")


        except FileNotFoundError:
            print(f"Error: File not found at {pkl_path}")
        except Exception as e:
            print(f"Error during inference dataset initialization from {pkl_path}: {e}")
            self.ids, self.imgs1, self.imgs2 = None, None, None


    def __len__(self):
        return len(self.ids) if self.ids is not None else 0

    def __getitem__(self, idx):
        if self.imgs1 is None or self.imgs2 is None or self.ids is None:
             raise IndexError("Inference dataset not initialized correctly.")

        im1_pil = Image.fromarray(self.imgs1[idx])
        im2_pil = Image.fromarray(self.imgs2[idx])
        current_id = self.ids[idx]

        # Apply only ToTensor and Normalize
        im1 = self.transform(im1_pil)
        im2 = self.transform(im2_pil)

        return im1, im2, current_id

print("Corrected Dataset classes defined.")
# Out:
# Corrected Dataset classes defined.

# %% [markdown]
# ## Model Definition

# %%
# Base Network (resnet18 for Feature Extractor)
def get_base_resnet18(pretrained=True):
    weights = models.ResNet34_Weights.DEFAULT if pretrained else None # 改成resnet 34
    backbone = models.resnet34(weights=weights)
    original_conv1 = backbone.conv1
    backbone.conv1 = nn.Conv2d(1, 64, kernel_size=3, stride=1, padding=1, bias=False)

    if pretrained and original_conv1.weight.shape[1] == 3:
        new_weights = original_conv1.weight.data.mean(dim=1, keepdim=True)
        backbone.conv1.weight.data = new_weights
        # print("Adapted pretrained weights for conv1 (1 channel input).") # Optional print

    num_ftrs = backbone.fc.in_features
    backbone.fc = nn.Identity() # Remove final classification layer

    return backbone, num_ftrs

# Siamese Network
class SiameseNet(nn.Module):
    def __init__(self, pretrained_base=True):
        super().__init__()
        self.base_network, num_base_ftrs = get_base_resnet18(pretrained=pretrained_base)
        self.classifier_head = nn.Sequential(
            nn.Linear(num_base_ftrs * 3, 128), # /change dim
            nn.ReLU(),
            nn.BatchNorm1d(128),
            nn.Dropout(0.8),
            nn.Linear(128, 2) # 2 classes for CrossEntropyLoss (0 or 1)
        )

    def forward(self, input1, input2):
        feat1 = self.base_network(input1)
        feat2 = self.base_network(input2)
        combined_features = torch.cat([feat1, feat2, torch.abs(feat1 - feat2)], dim=1) #torch.cat((feat1, feat2), dim=1)
        output = self.classifier_head(combined_features)
        return output

print("Model classes defined.")
# Out:
# Model classes defined.

# %% [markdown]
# ## Training

# %%
def train_one_epoch(model, loader, criterion, optimizer, device):
    model.train() # Set model to training mode
    total_loss = correct = total = 0
    #start_time = time.time()
    for batch_idx, (im1, im2, y) in enumerate(loader):
        im1, im2, y = im1.to(device), im2.to(device), y.to(device)
        optimizer.zero_grad()
        logits = model(im1, im2)
        loss = criterion(logits, y)
        loss.backward()
        optimizer.step()

        total_loss += loss.item() * im1.size(0)
        preds = logits.argmax(dim=1)
        correct += (preds == y).sum().item()
        total += y.size(0)

    avg_loss = total_loss / total if total > 0 else 0
    avg_acc = correct / total if total > 0 else 0
    #print(f"  Train Time: {epoch_time:.2f}s")
    return avg_loss, avg_acc

def validate(model, loader, criterion, device):
    model.eval()
    total_loss = correct = total = 0
    with torch.no_grad():
        for im1, im2, y in loader:
            im1, im2, y = im1.to(device), im2.to(device), y.to(device)
            logits = model(im1, im2)
            loss = criterion(logits, y)
            total_loss += loss.item() * im1.size(0)
            preds = logits.argmax(dim=1)
            correct += (preds == y).sum().item()
            total += y.size(0)

    avg_loss = total_loss / total if total > 0 else 0
    avg_acc = correct / total if total > 0 else 0
    return avg_loss, avg_acc

print("Training/validation functions defined.")

print("\n Starting Training Phase")

print("\n--- Starting K-Fold Cross-Validation Training Phase ---")

full_dataset = RPSSiameseDataset(TRAIN_PKL_PATH)

if len(full_dataset) == 0:
    print("Training aborted: Could not load training data.")
else:

    try:
        dataset_labels = full_dataset.labels.numpy() # Get labels as numpy array for StratifiedKFold
        dataset_indices = np.arange(len(full_dataset))
    except AttributeError:
         print("Error: Cannot access full_dataset.labels. Make sure it's accessible.")
         # Handle error appropriately, maybe exit or try loading labels differently
         dataset_labels = None

    if dataset_labels is not None:
        skf = StratifiedKFold(n_splits=K_FOLDS, shuffle=True, random_state=42)
        fold_results = [] # Store best val_acc for each fold
        total_training_start_time = time.time()

        # K-Fold Loop
        for fold, (train_idx, val_idx) in enumerate(skf.split(dataset_indices, dataset_labels), 1):
            print(f"\n===== Starting Fold {fold}/{K_FOLDS} =====")
            fold_start_time = time.time()

            train_subset = Subset(full_dataset, train_idx)
            val_subset = Subset(full_dataset, val_idx)

            train_loader = DataLoader(train_subset, batch_size=BATCH_SIZE, shuffle=True, num_workers=os.cpu_count()//2, pin_memory=True)
            val_loader = DataLoader(val_subset, batch_size=BATCH_SIZE, shuffle=False, num_workers=os.cpu_count()//2, pin_memory=True)
            print(f"Fold {fold}: Train batches={len(train_loader)}, Val batches={len(val_loader)}")

            model = SiameseNet(pretrained_base=USE_PRETRAINED_BASE).to(DEVICE)
            print(f"Fold {fold}: Initialized new model instance.")
            criterion = nn.CrossEntropyLoss(label_smoothing=0.1)
            optimizer = optim.AdamW(model.parameters(), lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY)
            scheduler = optim.lr_scheduler.ReduceLROnPlateau(
                optimizer, mode='max', factor=0.5, patience=PATIENCE_LR, verbose=False
            )

            best_fold_val_acc = 0.0
            epochs_no_improve = 0
            fold_model_save_path = MODEL_SAVE_PATH_TEMPLATE.format(fold=fold)

            for epoch in range(1, EPOCHS_PER_FOLD + 1):

                model.train()
                tr_loss, tr_acc = train_one_epoch(model, train_loader, criterion, optimizer, DEVICE) # Reusing train_one_epoch function

                model.eval()
                va_loss, va_acc = validate(model, val_loader, criterion, DEVICE) # Reusing validate function

                print(f"  Fold {fold} Epoch {epoch:2d} | Train Loss: {tr_loss:.4f}, Acc: {tr_acc:.4f} | Val Loss: {va_loss:.4f}, Acc: {va_acc:.4f}")

                scheduler.step(va_acc)

                if va_acc > best_fold_val_acc:
                    print(f"    🚀 Fold {fold} Val Acc improved to {va_acc:.4f}. Saving model to {fold_model_save_path}")
                    best_fold_val_acc = va_acc
                    torch.save(model.state_dict(), fold_model_save_path)
                    epochs_no_improve = 0
                else:
                    epochs_no_improve += 1
                    if epochs_no_improve >= PATIENCE_ES:
                        print(f"    🚨 Fold {fold} Early stopping triggered after epoch {epoch}. Best val acc: {best_fold_val_acc:.4f}")
                        break

            fold_duration = time.time() - fold_start_time
            print(f"===== Fold {fold} Finished in {fold_duration:.2f}s. Best Val Acc: {best_fold_val_acc:.4f} =====")
            fold_results.append(best_fold_val_acc)

        total_training_duration = time.time() - total_training_start_time
        print(f"\n--- K-Fold Training Finished ---")
        print(f"Total Training Time: {total_training_duration:.2f}s")
        print(f"Validation accuracies per fold: {[f'{acc:.4f}' for acc in fold_results]}")
        print(f"Average K-Fold Validation Accuracy: {np.mean(fold_results):.4f} (+/- {np.std(fold_results):.4f})")
# Out:
# Training/validation functions defined.
#
#  Starting Training Phase
#
# --- Starting K-Fold Cross-Validation Training Phase ---
# Pickle file 'train.pkl' loaded successfully.
# Attempting to stack 'img1' data...
#   'img1' stacked successfully. Shape: (40000, 24, 24)
# Attempting to stack 'img2' data...
#   'img2' stacked successfully. Shape: (40000, 24, 24)
# Dataset initialized successfully from train.pkl: 40000 samples.
#
# ===== Starting Fold 1/5 =====
# Fold 1: Train batches=1000, Val batches=250
# Fold 1: Initialized new model instance.
# /usr/local/lib/python3.11/dist-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
#   Fold 1 Epoch  1 | Train Loss: 0.8069, Acc: 0.5226 | Val Loss: 0.6847, Acc: 0.5986
#     🚀 Fold 1 Val Acc improved to 0.5986. Saving model to best_siamese_resnet_fold_1.pth
#   Fold 1 Epoch  2 | Train Loss: 0.6868, Acc: 0.6250 | Val Loss: 0.6165, Acc: 0.6739
#     🚀 Fold 1 Val Acc improved to 0.6739. Saving model to best_siamese_resnet_fold_1.pth
#   Fold 1 Epoch  3 | Train Loss: 0.6247, Acc: 0.6799 | Val Loss: 0.5970, Acc: 0.7070
#     🚀 Fold 1 Val Acc improved to 0.7070. Saving model to best_siamese_resnet_fold_1.pth
#   Fold 1 Epoch  4 | Train Loss: 0.5832, Acc: 0.7200 | Val Loss: 0.5696, Acc: 0.7430
#     🚀 Fold 1 Val Acc improved to 0.7430. Saving model to best_siamese_resnet_fold_1.pth
#   Fold 1 Epoch  5 | Train Loss: 0.5577, Acc: 0.7432 | Val Loss: 0.5406, Acc: 0.7594
#     🚀 Fold 1 Val Acc improved to 0.7594. Saving model to best_siamese_resnet_fold_1.pth
#   Fold 1 Epoch  6 | Train Loss: 0.5460, Acc: 0.7548 | Val Loss: 0.5304, Acc: 0.7614
#     🚀 Fold 1 Val Acc improved to 0.7614. Saving model to best_siamese_resnet_fold_1.pth
#   Fold 1 Epoch  7 | Train Loss: 0.5343, Acc: 0.7661 | Val Loss: 0.5211, Acc: 0.7762
#     🚀 Fold 1 Val Acc improved to 0.7762. Saving model to best_siamese_resnet_fold_1.pth
#   Fold 1 Epoch  8 | Train Loss: 0.5249, Acc: 0.7751 | Val Loss: 0.5089, Acc: 0.7775
#     🚀 Fold 1 Val Acc improved to 0.7775. Saving model to best_siamese_resnet_fold_1.pth
#   Fold 1 Epoch  9 | Train Loss: 0.5185, Acc: 0.7829 | Val Loss: 0.5167, Acc: 0.7778
#     🚀 Fold 1 Val Acc improved to 0.7778. Saving model to best_siamese_resnet_fold_1.pth
#   Fold 1 Epoch 10 | Train Loss: 0.5087, Acc: 0.7897 | Val Loss: 0.4948, Acc: 0.7910
#     🚀 Fold 1 Val Acc improved to 0.7910. Saving model to best_siamese_resnet_fold_1.pth
#   Fold 1 Epoch 11 | Train Loss: 0.5036, Acc: 0.7955 | Val Loss: 0.5066, Acc: 0.7911
#     🚀 Fold 1 Val Acc improved to 0.7911. Saving model to best_siamese_resnet_fold_1.pth
#   Fold 1 Epoch 12 | Train Loss: 0.4909, Acc: 0.8058 | Val Loss: 0.4926, Acc: 0.7987
#     🚀 Fold 1 Val Acc improved to 0.7987. Saving model to best_siamese_resnet_fold_1.pth
#   Fold 1 Epoch 13 | Train Loss: 0.4854, Acc: 0.8076 | Val Loss: 0.4864, Acc: 0.8046
#     🚀 Fold 1 Val Acc improved to 0.8046. Saving model to best_siamese_resnet_fold_1.pth
#   Fold 1 Epoch 14 | Train Loss: 0.4778, Acc: 0.8143 | Val Loss: 0.4891, Acc: 0.8006
#   Fold 1 Epoch 15 | Train Loss: 0.4761, Acc: 0.8179 | Val Loss: 0.4861, Acc: 0.7981
#   Fold 1 Epoch 16 | Train Loss: 0.4688, Acc: 0.8271 | Val Loss: 0.4789, Acc: 0.8075
#     🚀 Fold 1 Val Acc improved to 0.8075. Saving model to best_siamese_resnet_fold_1.pth
#   Fold 1 Epoch 17 | Train Loss: 0.4616, Acc: 0.8278 | Val Loss: 0.4760, Acc: 0.8097
#     🚀 Fold 1 Val Acc improved to 0.8097. Saving model to best_siamese_resnet_fold_1.pth
#   Fold 1 Epoch 18 | Train Loss: 0.4556, Acc: 0.8331 | Val Loss: 0.4689, Acc: 0.8144
#     🚀 Fold 1 Val Acc improved to 0.8144. Saving model to best_siamese_resnet_fold_1.pth
#   Fold 1 Epoch 19 | Train Loss: 0.4523, Acc: 0.8347 | Val Loss: 0.4629, Acc: 0.8160
#     🚀 Fold 1 Val Acc improved to 0.8160. Saving model to best_siamese_resnet_fold_1.pth
#   Fold 1 Epoch 20 | Train Loss: 0.4490, Acc: 0.8389 | Val Loss: 0.4655, Acc: 0.8115
#   Fold 1 Epoch 21 | Train Loss: 0.4404, Acc: 0.8443 | Val Loss: 0.4631, Acc: 0.8200
#     🚀 Fold 1 Val Acc improved to 0.8200. Saving model to best_siamese_resnet_fold_1.pth
#   Fold 1 Epoch 22 | Train Loss: 0.4399, Acc: 0.8461 | Val Loss: 0.4634, Acc: 0.8169
#   Fold 1 Epoch 23 | Train Loss: 0.4370, Acc: 0.8502 | Val Loss: 0.4634, Acc: 0.8217
#     🚀 Fold 1 Val Acc improved to 0.8217. Saving model to best_siamese_resnet_fold_1.pth
#   Fold 1 Epoch 24 | Train Loss: 0.4261, Acc: 0.8569 | Val Loss: 0.4624, Acc: 0.8216
#   Fold 1 Epoch 25 | Train Loss: 0.4219, Acc: 0.8597 | Val Loss: 0.4625, Acc: 0.8240
#     🚀 Fold 1 Val Acc improved to 0.8240. Saving model to best_siamese_resnet_fold_1.pth
#   Fold 1 Epoch 26 | Train Loss: 0.4171, Acc: 0.8619 | Val Loss: 0.4641, Acc: 0.8209
#   Fold 1 Epoch 27 | Train Loss: 0.4126, Acc: 0.8688 | Val Loss: 0.4599, Acc: 0.8193
#   Fold 1 Epoch 28 | Train Loss: 0.4103, Acc: 0.8695 | Val Loss: 0.4534, Acc: 0.8289
#     🚀 Fold 1 Val Acc improved to 0.8289. Saving model to best_siamese_resnet_fold_1.pth
#   Fold 1 Epoch 29 | Train Loss: 0.4061, Acc: 0.8719 | Val Loss: 0.4525, Acc: 0.8313
#     🚀 Fold 1 Val Acc improved to 0.8313. Saving model to best_siamese_resnet_fold_1.pth
#   Fold 1 Epoch 30 | Train Loss: 0.3993, Acc: 0.8791 | Val Loss: 0.4582, Acc: 0.8229
#   Fold 1 Epoch 31 | Train Loss: 0.3980, Acc: 0.8781 | Val Loss: 0.4593, Acc: 0.8249
#   Fold 1 Epoch 32 | Train Loss: 0.3900, Acc: 0.8844 | Val Loss: 0.4547, Acc: 0.8251
#   Fold 1 Epoch 33 | Train Loss: 0.3892, Acc: 0.8853 | Val Loss: 0.4529, Acc: 0.8343
#     🚀 Fold 1 Val Acc improved to 0.8343. Saving model to best_siamese_resnet_fold_1.pth
#   Fold 1 Epoch 34 | Train Loss: 0.3857, Acc: 0.8867 | Val Loss: 0.4523, Acc: 0.8304
#   Fold 1 Epoch 35 | Train Loss: 0.3838, Acc: 0.8908 | Val Loss: 0.4558, Acc: 0.8296
#   Fold 1 Epoch 36 | Train Loss: 0.3798, Acc: 0.8932 | Val Loss: 0.4517, Acc: 0.8357
#     🚀 Fold 1 Val Acc improved to 0.8357. Saving model to best_siamese_resnet_fold_1.pth
#   Fold 1 Epoch 37 | Train Loss: 0.3756, Acc: 0.8979 | Val Loss: 0.4503, Acc: 0.8350
#   Fold 1 Epoch 38 | Train Loss: 0.3689, Acc: 0.9006 | Val Loss: 0.4690, Acc: 0.8294
#   Fold 1 Epoch 39 | Train Loss: 0.3688, Acc: 0.9024 | Val Loss: 0.4648, Acc: 0.8340
#   Fold 1 Epoch 40 | Train Loss: 0.3650, Acc: 0.9046 | Val Loss: 0.4589, Acc: 0.8315
#   Fold 1 Epoch 41 | Train Loss: 0.3417, Acc: 0.9190 | Val Loss: 0.4616, Acc: 0.8346
#   Fold 1 Epoch 42 | Train Loss: 0.3341, Acc: 0.9262 | Val Loss: 0.4575, Acc: 0.8386
#     🚀 Fold 1 Val Acc improved to 0.8386. Saving model to best_siamese_resnet_fold_1.pth
#   Fold 1 Epoch 43 | Train Loss: 0.3290, Acc: 0.9306 | Val Loss: 0.4594, Acc: 0.8409
#     🚀 Fold 1 Val Acc improved to 0.8409. Saving model to best_siamese_resnet_fold_1.pth
#   Fold 1 Epoch 44 | Train Loss: 0.3213, Acc: 0.9335 | Val Loss: 0.4565, Acc: 0.8414
#     🚀 Fold 1 Val Acc improved to 0.8414. Saving model to best_siamese_resnet_fold_1.pth
#   Fold 1 Epoch 45 | Train Loss: 0.3215, Acc: 0.9350 | Val Loss: 0.4675, Acc: 0.8396
#   Fold 1 Epoch 46 | Train Loss: 0.3186, Acc: 0.9363 | Val Loss: 0.4623, Acc: 0.8441
#     🚀 Fold 1 Val Acc improved to 0.8441. Saving model to best_siamese_resnet_fold_1.pth
#   Fold 1 Epoch 47 | Train Loss: 0.3146, Acc: 0.9375 | Val Loss: 0.4523, Acc: 0.8445
#     🚀 Fold 1 Val Acc improved to 0.8445. Saving model to best_siamese_resnet_fold_1.pth
#   Fold 1 Epoch 48 | Train Loss: 0.3146, Acc: 0.9397 | Val Loss: 0.4716, Acc: 0.8355
#   Fold 1 Epoch 49 | Train Loss: 0.3082, Acc: 0.9428 | Val Loss: 0.4584, Acc: 0.8440
#   Fold 1 Epoch 50 | Train Loss: 0.3079, Acc: 0.9437 | Val Loss: 0.4666, Acc: 0.8455
#     🚀 Fold 1 Val Acc improved to 0.8455. Saving model to best_siamese_resnet_fold_1.pth
#   Fold 1 Epoch 51 | Train Loss: 0.3077, Acc: 0.9431 | Val Loss: 0.4731, Acc: 0.8421
#   Fold 1 Epoch 52 | Train Loss: 0.3030, Acc: 0.9467 | Val Loss: 0.4776, Acc: 0.8393
#   Fold 1 Epoch 53 | Train Loss: 0.3038, Acc: 0.9471 | Val Loss: 0.4713, Acc: 0.8438
#   Fold 1 Epoch 54 | Train Loss: 0.3009, Acc: 0.9479 | Val Loss: 0.4741, Acc: 0.8391
#   Fold 1 Epoch 55 | Train Loss: 0.2876, Acc: 0.9562 | Val Loss: 0.4844, Acc: 0.8423
#   Fold 1 Epoch 56 | Train Loss: 0.2836, Acc: 0.9585 | Val Loss: 0.4841, Acc: 0.8400
#   Fold 1 Epoch 57 | Train Loss: 0.2817, Acc: 0.9593 | Val Loss: 0.4754, Acc: 0.8506
#     🚀 Fold 1 Val Acc improved to 0.8506. Saving model to best_siamese_resnet_fold_1.pth
#   Fold 1 Epoch 58 | Train Loss: 0.2804, Acc: 0.9604 | Val Loss: 0.4832, Acc: 0.8446
#   Fold 1 Epoch 59 | Train Loss: 0.2782, Acc: 0.9613 | Val Loss: 0.4809, Acc: 0.8444
#   Fold 1 Epoch 60 | Train Loss: 0.2771, Acc: 0.9621 | Val Loss: 0.4891, Acc: 0.8444
#   Fold 1 Epoch 61 | Train Loss: 0.2761, Acc: 0.9629 | Val Loss: 0.4833, Acc: 0.8445
#   Fold 1 Epoch 62 | Train Loss: 0.2742, Acc: 0.9656 | Val Loss: 0.4911, Acc: 0.8465
#   Fold 1 Epoch 63 | Train Loss: 0.2678, Acc: 0.9692 | Val Loss: 0.4785, Acc: 0.8490
#   Fold 1 Epoch 64 | Train Loss: 0.2693, Acc: 0.9679 | Val Loss: 0.4850, Acc: 0.8423
#   Fold 1 Epoch 65 | Train Loss: 0.2641, Acc: 0.9706 | Val Loss: 0.4783, Acc: 0.8519
#     🚀 Fold 1 Val Acc improved to 0.8519. Saving model to best_siamese_resnet_fold_1.pth
#   Fold 1 Epoch 66 | Train Loss: 0.2661, Acc: 0.9706 | Val Loss: 0.4915, Acc: 0.8470
#   Fold 1 Epoch 67 | Train Loss: 0.2642, Acc: 0.9712 | Val Loss: 0.4880, Acc: 0.8438
#   Fold 1 Epoch 68 | Train Loss: 0.2623, Acc: 0.9721 | Val Loss: 0.4714, Acc: 0.8558
#     🚀 Fold 1 Val Acc improved to 0.8558. Saving model to best_siamese_resnet_fold_1.pth
#   Fold 1 Epoch 69 | Train Loss: 0.2647, Acc: 0.9717 | Val Loss: 0.4959, Acc: 0.8456
#   Fold 1 Epoch 70 | Train Loss: 0.2602, Acc: 0.9726 | Val Loss: 0.4970, Acc: 0.8460
#   Fold 1 Epoch 71 | Train Loss: 0.2610, Acc: 0.9733 | Val Loss: 0.4886, Acc: 0.8484
#   Fold 1 Epoch 72 | Train Loss: 0.2614, Acc: 0.9726 | Val Loss: 0.4914, Acc: 0.8429
#   Fold 1 Epoch 73 | Train Loss: 0.2570, Acc: 0.9752 | Val Loss: 0.4909, Acc: 0.8501
#   Fold 1 Epoch 74 | Train Loss: 0.2586, Acc: 0.9758 | Val Loss: 0.4951, Acc: 0.8485
#   Fold 1 Epoch 75 | Train Loss: 0.2579, Acc: 0.9751 | Val Loss: 0.5041, Acc: 0.8426
#   Fold 1 Epoch 76 | Train Loss: 0.2562, Acc: 0.9763 | Val Loss: 0.4894, Acc: 0.8499
#   Fold 1 Epoch 77 | Train Loss: 0.2580, Acc: 0.9762 | Val Loss: 0.4841, Acc: 0.8499
#   Fold 1 Epoch 78 | Train Loss: 0.2564, Acc: 0.9760 | Val Loss: 0.4906, Acc: 0.8472
#   Fold 1 Epoch 79 | Train Loss: 0.2561, Acc: 0.9762 | Val Loss: 0.4895, Acc: 0.8471
#   Fold 1 Epoch 80 | Train Loss: 0.2550, Acc: 0.9762 | Val Loss: 0.4837, Acc: 0.8491
# ===== Fold 1 Finished in 3675.41s. Best Val Acc: 0.8558 =====
#
# ===== Starting Fold 2/5 =====
# Fold 2: Train batches=1000, Val batches=250
# Fold 2: Initialized new model instance.
#   Fold 2 Epoch  1 | Train Loss: 0.8006, Acc: 0.5378 | Val Loss: 0.6629, Acc: 0.6146
#     🚀 Fold 2 Val Acc improved to 0.6146. Saving model to best_siamese_resnet_fold_2.pth
#   Fold 2 Epoch  2 | Train Loss: 0.6670, Acc: 0.6308 | Val Loss: 0.6176, Acc: 0.6965
#     🚀 Fold 2 Val Acc improved to 0.6965. Saving model to best_siamese_resnet_fold_2.pth
#   Fold 2 Epoch  3 | Train Loss: 0.6106, Acc: 0.6909 | Val Loss: 0.5699, Acc: 0.7314
#     🚀 Fold 2 Val Acc improved to 0.7314. Saving model to best_siamese_resnet_fold_2.pth
#   Fold 2 Epoch  4 | Train Loss: 0.5786, Acc: 0.7249 | Val Loss: 0.5502, Acc: 0.7470
#     🚀 Fold 2 Val Acc improved to 0.7470. Saving model to best_siamese_resnet_fold_2.pth
#   Fold 2 Epoch  5 | Train Loss: 0.5596, Acc: 0.7449 | Val Loss: 0.5347, Acc: 0.7616
#     🚀 Fold 2 Val Acc improved to 0.7616. Saving model to best_siamese_resnet_fold_2.pth
#   Fold 2 Epoch  6 | Train Loss: 0.5481, Acc: 0.7567 | Val Loss: 0.5206, Acc: 0.7691
#     🚀 Fold 2 Val Acc improved to 0.7691. Saving model to best_siamese_resnet_fold_2.pth
#   Fold 2 Epoch  7 | Train Loss: 0.5378, Acc: 0.7638 | Val Loss: 0.5106, Acc: 0.7855
#     🚀 Fold 2 Val Acc improved to 0.7855. Saving model to best_siamese_resnet_fold_2.pth
#   Fold 2 Epoch  8 | Train Loss: 0.5265, Acc: 0.7746 | Val Loss: 0.5145, Acc: 0.7812
#   Fold 2 Epoch  9 | Train Loss: 0.5187, Acc: 0.7809 | Val Loss: 0.5039, Acc: 0.7844
#   Fold 2 Epoch 10 | Train Loss: 0.5139, Acc: 0.7866 | Val Loss: 0.5110, Acc: 0.7826
#   Fold 2 Epoch 11 | Train Loss: 0.5049, Acc: 0.7938 | Val Loss: 0.4914, Acc: 0.8011
#     🚀 Fold 2 Val Acc improved to 0.8011. Saving model to best_siamese_resnet_fold_2.pth
#   Fold 2 Epoch 12 | Train Loss: 0.4989, Acc: 0.7990 | Val Loss: 0.4856, Acc: 0.8050
#     🚀 Fold 2 Val Acc improved to 0.8050. Saving model to best_siamese_resnet_fold_2.pth
#   Fold 2 Epoch 13 | Train Loss: 0.4902, Acc: 0.8041 | Val Loss: 0.4752, Acc: 0.8123
#     🚀 Fold 2 Val Acc improved to 0.8123. Saving model to best_siamese_resnet_fold_2.pth
#   Fold 2 Epoch 14 | Train Loss: 0.4865, Acc: 0.8095 | Val Loss: 0.4751, Acc: 0.8087
#   Fold 2 Epoch 15 | Train Loss: 0.4787, Acc: 0.8161 | Val Loss: 0.4746, Acc: 0.8117
#   Fold 2 Epoch 16 | Train Loss: 0.4718, Acc: 0.8222 | Val Loss: 0.4733, Acc: 0.8120
#   Fold 2 Epoch 17 | Train Loss: 0.4669, Acc: 0.8275 | Val Loss: 0.4764, Acc: 0.8091
#   Fold 2 Epoch 18 | Train Loss: 0.4432, Acc: 0.8435 | Val Loss: 0.4533, Acc: 0.8231
#     🚀 Fold 2 Val Acc improved to 0.8231. Saving model to best_siamese_resnet_fold_2.pth
#   Fold 2 Epoch 19 | Train Loss: 0.4340, Acc: 0.8497 | Val Loss: 0.4532, Acc: 0.8253
#     🚀 Fold 2 Val Acc improved to 0.8253. Saving model to best_siamese_resnet_fold_2.pth
#   Fold 2 Epoch 20 | Train Loss: 0.4299, Acc: 0.8535 | Val Loss: 0.4541, Acc: 0.8269
#     🚀 Fold 2 Val Acc improved to 0.8269. Saving model to best_siamese_resnet_fold_2.pth
#   Fold 2 Epoch 21 | Train Loss: 0.4235, Acc: 0.8582 | Val Loss: 0.4477, Acc: 0.8306
#     🚀 Fold 2 Val Acc improved to 0.8306. Saving model to best_siamese_resnet_fold_2.pth
#   Fold 2 Epoch 22 | Train Loss: 0.4165, Acc: 0.8621 | Val Loss: 0.4501, Acc: 0.8311
#     🚀 Fold 2 Val Acc improved to 0.8311. Saving model to best_siamese_resnet_fold_2.pth
#   Fold 2 Epoch 23 | Train Loss: 0.4131, Acc: 0.8672 | Val Loss: 0.4500, Acc: 0.8283
#   Fold 2 Epoch 24 | Train Loss: 0.4060, Acc: 0.8713 | Val Loss: 0.4552, Acc: 0.8264
#   Fold 2 Epoch 25 | Train Loss: 0.4035, Acc: 0.8748 | Val Loss: 0.4508, Acc: 0.8296
#   Fold 2 Epoch 26 | Train Loss: 0.3960, Acc: 0.8798 | Val Loss: 0.4558, Acc: 0.8275
#   Fold 2 Epoch 27 | Train Loss: 0.3857, Acc: 0.8870 | Val Loss: 0.4435, Acc: 0.8379
#     🚀 Fold 2 Val Acc improved to 0.8379. Saving model to best_siamese_resnet_fold_2.pth
#   Fold 2 Epoch 28 | Train Loss: 0.3743, Acc: 0.8976 | Val Loss: 0.4488, Acc: 0.8337
#   Fold 2 Epoch 29 | Train Loss: 0.3729, Acc: 0.8973 | Val Loss: 0.4518, Acc: 0.8304
#   Fold 2 Epoch 30 | Train Loss: 0.3668, Acc: 0.9015 | Val Loss: 0.4454, Acc: 0.8343
#   Fold 2 Epoch 31 | Train Loss: 0.3630, Acc: 0.9042 | Val Loss: 0.4500, Acc: 0.8339
#   Fold 2 Epoch 32 | Train Loss: 0.3571, Acc: 0.9069 | Val Loss: 0.4478, Acc: 0.8405
#     🚀 Fold 2 Val Acc improved to 0.8405. Saving model to best_siamese_resnet_fold_2.pth
#   Fold 2 Epoch 33 | Train Loss: 0.3508, Acc: 0.9115 | Val Loss: 0.4467, Acc: 0.8373
#   Fold 2 Epoch 34 | Train Loss: 0.3491, Acc: 0.9130 | Val Loss: 0.4542, Acc: 0.8383
#   Fold 2 Epoch 35 | Train Loss: 0.3463, Acc: 0.9159 | Val Loss: 0.4519, Acc: 0.8373
#   Fold 2 Epoch 36 | Train Loss: 0.3457, Acc: 0.9154 | Val Loss: 0.4488, Acc: 0.8430
#     🚀 Fold 2 Val Acc improved to 0.8430. Saving model to best_siamese_resnet_fold_2.pth
#   Fold 2 Epoch 37 | Train Loss: 0.3419, Acc: 0.9176 | Val Loss: 0.4577, Acc: 0.8389
#   Fold 2 Epoch 38 | Train Loss: 0.3382, Acc: 0.9202 | Val Loss: 0.4500, Acc: 0.8410
#   Fold 2 Epoch 39 | Train Loss: 0.3389, Acc: 0.9208 | Val Loss: 0.4562, Acc: 0.8389
#   Fold 2 Epoch 40 | Train Loss: 0.3347, Acc: 0.9217 | Val Loss: 0.4554, Acc: 0.8431
#     🚀 Fold 2 Val Acc improved to 0.8431. Saving model to best_siamese_resnet_fold_2.pth
#   Fold 2 Epoch 41 | Train Loss: 0.3369, Acc: 0.9232 | Val Loss: 0.4534, Acc: 0.8419
#   Fold 2 Epoch 42 | Train Loss: 0.3316, Acc: 0.9262 | Val Loss: 0.4622, Acc: 0.8365
#   Fold 2 Epoch 43 | Train Loss: 0.3304, Acc: 0.9258 | Val Loss: 0.4464, Acc: 0.8461
#     🚀 Fold 2 Val Acc improved to 0.8461. Saving model to best_siamese_resnet_fold_2.pth
#   Fold 2 Epoch 44 | Train Loss: 0.3262, Acc: 0.9291 | Val Loss: 0.4629, Acc: 0.8381
#   Fold 2 Epoch 45 | Train Loss: 0.3265, Acc: 0.9286 | Val Loss: 0.4637, Acc: 0.8399
#   Fold 2 Epoch 46 | Train Loss: 0.3281, Acc: 0.9285 | Val Loss: 0.4565, Acc: 0.8458
#   Fold 2 Epoch 47 | Train Loss: 0.3257, Acc: 0.9296 | Val Loss: 0.4596, Acc: 0.8396
#   Fold 2 Epoch 48 | Train Loss: 0.3184, Acc: 0.9341 | Val Loss: 0.4576, Acc: 0.8454
#   Fold 2 Epoch 49 | Train Loss: 0.3172, Acc: 0.9360 | Val Loss: 0.4672, Acc: 0.8406
#   Fold 2 Epoch 50 | Train Loss: 0.3171, Acc: 0.9349 | Val Loss: 0.4602, Acc: 0.8429
#   Fold 2 Epoch 51 | Train Loss: 0.3181, Acc: 0.9353 | Val Loss: 0.4656, Acc: 0.8404
#   Fold 2 Epoch 52 | Train Loss: 0.3140, Acc: 0.9372 | Val Loss: 0.4632, Acc: 0.8455
#   Fold 2 Epoch 53 | Train Loss: 0.3137, Acc: 0.9381 | Val Loss: 0.4680, Acc: 0.8391
#   Fold 2 Epoch 54 | Train Loss: 0.3130, Acc: 0.9374 | Val Loss: 0.4668, Acc: 0.8387
#   Fold 2 Epoch 55 | Train Loss: 0.3103, Acc: 0.9395 | Val Loss: 0.4609, Acc: 0.8439
#   Fold 2 Epoch 56 | Train Loss: 0.3116, Acc: 0.9393 | Val Loss: 0.4666, Acc: 0.8411
#   Fold 2 Epoch 57 | Train Loss: 0.3088, Acc: 0.9415 | Val Loss: 0.4664, Acc: 0.8417
#   Fold 2 Epoch 58 | Train Loss: 0.3111, Acc: 0.9414 | Val Loss: 0.4589, Acc: 0.8436
#   Fold 2 Epoch 59 | Train Loss: 0.3075, Acc: 0.9405 | Val Loss: 0.4656, Acc: 0.8411
#   Fold 2 Epoch 60 | Train Loss: 0.3075, Acc: 0.9426 | Val Loss: 0.4674, Acc: 0.8416
#   Fold 2 Epoch 61 | Train Loss: 0.3069, Acc: 0.9423 | Val Loss: 0.4700, Acc: 0.8403
#   Fold 2 Epoch 62 | Train Loss: 0.3099, Acc: 0.9405 | Val Loss: 0.4672, Acc: 0.8438
#   Fold 2 Epoch 63 | Train Loss: 0.3093, Acc: 0.9413 | Val Loss: 0.4614, Acc: 0.8448
#     🚨 Fold 2 Early stopping triggered after epoch 63. Best val acc: 0.8461
# ===== Fold 2 Finished in 2881.36s. Best Val Acc: 0.8461 =====
#
# ===== Starting Fold 3/5 =====
# Fold 3: Train batches=1000, Val batches=250
# Fold 3: Initialized new model instance.
#   Fold 3 Epoch  1 | Train Loss: 0.8242, Acc: 0.5428 | Val Loss: 0.6724, Acc: 0.6322
#     🚀 Fold 3 Val Acc improved to 0.6322. Saving model to best_siamese_resnet_fold_3.pth
#   Fold 3 Epoch  2 | Train Loss: 0.6778, Acc: 0.6469 | Val Loss: 0.6071, Acc: 0.6884
#     🚀 Fold 3 Val Acc improved to 0.6884. Saving model to best_siamese_resnet_fold_3.pth
#   Fold 3 Epoch  3 | Train Loss: 0.6064, Acc: 0.7015 | Val Loss: 0.5738, Acc: 0.7231
#     🚀 Fold 3 Val Acc improved to 0.7231. Saving model to best_siamese_resnet_fold_3.pth
#   Fold 3 Epoch  4 | Train Loss: 0.5756, Acc: 0.7302 | Val Loss: 0.5551, Acc: 0.7359
#     🚀 Fold 3 Val Acc improved to 0.7359. Saving model to best_siamese_resnet_fold_3.pth
#   Fold 3 Epoch  5 | Train Loss: 0.5530, Acc: 0.7496 | Val Loss: 0.5361, Acc: 0.7550
#     🚀 Fold 3 Val Acc improved to 0.7550. Saving model to best_siamese_resnet_fold_3.pth
#   Fold 3 Epoch  6 | Train Loss: 0.5402, Acc: 0.7601 | Val Loss: 0.5329, Acc: 0.7609
#     🚀 Fold 3 Val Acc improved to 0.7609. Saving model to best_siamese_resnet_fold_3.pth
#   Fold 3 Epoch  7 | Train Loss: 0.5326, Acc: 0.7709 | Val Loss: 0.5135, Acc: 0.7780
#     🚀 Fold 3 Val Acc improved to 0.7780. Saving model to best_siamese_resnet_fold_3.pth
#   Fold 3 Epoch  8 | Train Loss: 0.5216, Acc: 0.7765 | Val Loss: 0.5084, Acc: 0.7855
#     🚀 Fold 3 Val Acc improved to 0.7855. Saving model to best_siamese_resnet_fold_3.pth
#   Fold 3 Epoch  9 | Train Loss: 0.5104, Acc: 0.7899 | Val Loss: 0.5103, Acc: 0.7827
#   Fold 3 Epoch 10 | Train Loss: 0.5044, Acc: 0.7913 | Val Loss: 0.5153, Acc: 0.7750
#   Fold 3 Epoch 11 | Train Loss: 0.4955, Acc: 0.7994 | Val Loss: 0.4984, Acc: 0.7947
#     🚀 Fold 3 Val Acc improved to 0.7947. Saving model to best_siamese_resnet_fold_3.pth
#   Fold 3 Epoch 12 | Train Loss: 0.4913, Acc: 0.8041 | Val Loss: 0.4878, Acc: 0.7943
#   Fold 3 Epoch 13 | Train Loss: 0.4837, Acc: 0.8090 | Val Loss: 0.4848, Acc: 0.8007
#     🚀 Fold 3 Val Acc improved to 0.8007. Saving model to best_siamese_resnet_fold_3.pth
#   Fold 3 Epoch 14 | Train Loss: 0.4763, Acc: 0.8169 | Val Loss: 0.4774, Acc: 0.8106
#     🚀 Fold 3 Val Acc improved to 0.8106. Saving model to best_siamese_resnet_fold_3.pth
#   Fold 3 Epoch 15 | Train Loss: 0.4698, Acc: 0.8194 | Val Loss: 0.4711, Acc: 0.8114
#     🚀 Fold 3 Val Acc improved to 0.8114. Saving model to best_siamese_resnet_fold_3.pth
#   Fold 3 Epoch 16 | Train Loss: 0.4633, Acc: 0.8273 | Val Loss: 0.4782, Acc: 0.8064
#   Fold 3 Epoch 17 | Train Loss: 0.4592, Acc: 0.8287 | Val Loss: 0.4730, Acc: 0.8134
#     🚀 Fold 3 Val Acc improved to 0.8134. Saving model to best_siamese_resnet_fold_3.pth
#   Fold 3 Epoch 18 | Train Loss: 0.4524, Acc: 0.8355 | Val Loss: 0.4779, Acc: 0.8037
#   Fold 3 Epoch 19 | Train Loss: 0.4476, Acc: 0.8393 | Val Loss: 0.4730, Acc: 0.8116
#   Fold 3 Epoch 20 | Train Loss: 0.4424, Acc: 0.8431 | Val Loss: 0.4740, Acc: 0.8110
#   Fold 3 Epoch 21 | Train Loss: 0.4337, Acc: 0.8496 | Val Loss: 0.4694, Acc: 0.8170
#     🚀 Fold 3 Val Acc improved to 0.8170. Saving model to best_siamese_resnet_fold_3.pth
#   Fold 3 Epoch 22 | Train Loss: 0.4327, Acc: 0.8526 | Val Loss: 0.4582, Acc: 0.8229
#     🚀 Fold 3 Val Acc improved to 0.8229. Saving model to best_siamese_resnet_fold_3.pth
#   Fold 3 Epoch 23 | Train Loss: 0.4239, Acc: 0.8577 | Val Loss: 0.4645, Acc: 0.8195
#   Fold 3 Epoch 24 | Train Loss: 0.4210, Acc: 0.8593 | Val Loss: 0.4586, Acc: 0.8257
#     🚀 Fold 3 Val Acc improved to 0.8257. Saving model to best_siamese_resnet_fold_3.pth
#   Fold 3 Epoch 25 | Train Loss: 0.4197, Acc: 0.8614 | Val Loss: 0.4547, Acc: 0.8237
#   Fold 3 Epoch 26 | Train Loss: 0.4127, Acc: 0.8673 | Val Loss: 0.4653, Acc: 0.8223
#   Fold 3 Epoch 27 | Train Loss: 0.4078, Acc: 0.8699 | Val Loss: 0.4709, Acc: 0.8223
#   Fold 3 Epoch 28 | Train Loss: 0.4009, Acc: 0.8764 | Val Loss: 0.4663, Acc: 0.8209
#   Fold 3 Epoch 29 | Train Loss: 0.3828, Acc: 0.8888 | Val Loss: 0.4535, Acc: 0.8311
#     🚀 Fold 3 Val Acc improved to 0.8311. Saving model to best_siamese_resnet_fold_3.pth
#   Fold 3 Epoch 30 | Train Loss: 0.3700, Acc: 0.8974 | Val Loss: 0.4569, Acc: 0.8303
#   Fold 3 Epoch 31 | Train Loss: 0.3674, Acc: 0.8982 | Val Loss: 0.4545, Acc: 0.8375
#     🚀 Fold 3 Val Acc improved to 0.8375. Saving model to best_siamese_resnet_fold_3.pth
#   Fold 3 Epoch 32 | Train Loss: 0.3588, Acc: 0.9057 | Val Loss: 0.4605, Acc: 0.8310
#   Fold 3 Epoch 33 | Train Loss: 0.3568, Acc: 0.9083 | Val Loss: 0.4614, Acc: 0.8334
#   Fold 3 Epoch 34 | Train Loss: 0.3520, Acc: 0.9106 | Val Loss: 0.4606, Acc: 0.8317
#   Fold 3 Epoch 35 | Train Loss: 0.3489, Acc: 0.9150 | Val Loss: 0.4622, Acc: 0.8343
#   Fold 3 Epoch 36 | Train Loss: 0.3373, Acc: 0.9231 | Val Loss: 0.4658, Acc: 0.8331
#   Fold 3 Epoch 37 | Train Loss: 0.3316, Acc: 0.9267 | Val Loss: 0.4566, Acc: 0.8381
#     🚀 Fold 3 Val Acc improved to 0.8381. Saving model to best_siamese_resnet_fold_3.pth
#   Fold 3 Epoch 38 | Train Loss: 0.3263, Acc: 0.9303 | Val Loss: 0.4625, Acc: 0.8376
#   Fold 3 Epoch 39 | Train Loss: 0.3274, Acc: 0.9288 | Val Loss: 0.4575, Acc: 0.8401
#     🚀 Fold 3 Val Acc improved to 0.8401. Saving model to best_siamese_resnet_fold_3.pth
#   Fold 3 Epoch 40 | Train Loss: 0.3238, Acc: 0.9314 | Val Loss: 0.4629, Acc: 0.8357
#   Fold 3 Epoch 41 | Train Loss: 0.3187, Acc: 0.9350 | Val Loss: 0.4668, Acc: 0.8403
#     🚀 Fold 3 Val Acc improved to 0.8403. Saving model to best_siamese_resnet_fold_3.pth
#   Fold 3 Epoch 42 | Train Loss: 0.3179, Acc: 0.9350 | Val Loss: 0.4605, Acc: 0.8390
#   Fold 3 Epoch 43 | Train Loss: 0.3180, Acc: 0.9361 | Val Loss: 0.4631, Acc: 0.8395
#   Fold 3 Epoch 44 | Train Loss: 0.3142, Acc: 0.9372 | Val Loss: 0.4589, Acc: 0.8423
#     🚀 Fold 3 Val Acc improved to 0.8423. Saving model to best_siamese_resnet_fold_3.pth
#   Fold 3 Epoch 45 | Train Loss: 0.3108, Acc: 0.9404 | Val Loss: 0.4632, Acc: 0.8455
#     🚀 Fold 3 Val Acc improved to 0.8455. Saving model to best_siamese_resnet_fold_3.pth
#   Fold 3 Epoch 46 | Train Loss: 0.3094, Acc: 0.9399 | Val Loss: 0.4657, Acc: 0.8406
#   Fold 3 Epoch 47 | Train Loss: 0.3065, Acc: 0.9423 | Val Loss: 0.4713, Acc: 0.8390
#   Fold 3 Epoch 48 | Train Loss: 0.3033, Acc: 0.9450 | Val Loss: 0.4719, Acc: 0.8376
#   Fold 3 Epoch 49 | Train Loss: 0.3074, Acc: 0.9427 | Val Loss: 0.4746, Acc: 0.8350
#   Fold 3 Epoch 50 | Train Loss: 0.2957, Acc: 0.9494 | Val Loss: 0.4674, Acc: 0.8489
#     🚀 Fold 3 Val Acc improved to 0.8489. Saving model to best_siamese_resnet_fold_3.pth
#   Fold 3 Epoch 51 | Train Loss: 0.2972, Acc: 0.9483 | Val Loss: 0.4669, Acc: 0.8458
#   Fold 3 Epoch 52 | Train Loss: 0.2931, Acc: 0.9513 | Val Loss: 0.4753, Acc: 0.8433
#   Fold 3 Epoch 53 | Train Loss: 0.2923, Acc: 0.9521 | Val Loss: 0.4854, Acc: 0.8390
#   Fold 3 Epoch 54 | Train Loss: 0.2894, Acc: 0.9554 | Val Loss: 0.4772, Acc: 0.8426
#   Fold 3 Epoch 55 | Train Loss: 0.2881, Acc: 0.9555 | Val Loss: 0.4873, Acc: 0.8407
#   Fold 3 Epoch 56 | Train Loss: 0.2875, Acc: 0.9549 | Val Loss: 0.4779, Acc: 0.8445
#   Fold 3 Epoch 57 | Train Loss: 0.2836, Acc: 0.9591 | Val Loss: 0.4685, Acc: 0.8516
#     🚀 Fold 3 Val Acc improved to 0.8516. Saving model to best_siamese_resnet_fold_3.pth
#   Fold 3 Epoch 58 | Train Loss: 0.2870, Acc: 0.9560 | Val Loss: 0.4793, Acc: 0.8464
#   Fold 3 Epoch 59 | Train Loss: 0.2844, Acc: 0.9579 | Val Loss: 0.4790, Acc: 0.8466
#   Fold 3 Epoch 60 | Train Loss: 0.2855, Acc: 0.9577 | Val Loss: 0.4695, Acc: 0.8480
#   Fold 3 Epoch 61 | Train Loss: 0.2803, Acc: 0.9597 | Val Loss: 0.4895, Acc: 0.8417
#   Fold 3 Epoch 62 | Train Loss: 0.2795, Acc: 0.9610 | Val Loss: 0.4848, Acc: 0.8442
#   Fold 3 Epoch 63 | Train Loss: 0.2797, Acc: 0.9597 | Val Loss: 0.4787, Acc: 0.8444
#   Fold 3 Epoch 64 | Train Loss: 0.2799, Acc: 0.9592 | Val Loss: 0.4807, Acc: 0.8438
#   Fold 3 Epoch 65 | Train Loss: 0.2798, Acc: 0.9598 | Val Loss: 0.4934, Acc: 0.8410
#   Fold 3 Epoch 66 | Train Loss: 0.2788, Acc: 0.9608 | Val Loss: 0.4837, Acc: 0.8429
#   Fold 3 Epoch 67 | Train Loss: 0.2795, Acc: 0.9597 | Val Loss: 0.4886, Acc: 0.8397
#   Fold 3 Epoch 68 | Train Loss: 0.2781, Acc: 0.9603 | Val Loss: 0.4874, Acc: 0.8415
#   Fold 3 Epoch 69 | Train Loss: 0.2787, Acc: 0.9610 | Val Loss: 0.4769, Acc: 0.8465
#   Fold 3 Epoch 70 | Train Loss: 0.2764, Acc: 0.9630 | Val Loss: 0.4851, Acc: 0.8431
#   Fold 3 Epoch 71 | Train Loss: 0.2785, Acc: 0.9616 | Val Loss: 0.4860, Acc: 0.8404
#   Fold 3 Epoch 72 | Train Loss: 0.2771, Acc: 0.9630 | Val Loss: 0.4750, Acc: 0.8458
#   Fold 3 Epoch 73 | Train Loss: 0.2770, Acc: 0.9625 | Val Loss: 0.4810, Acc: 0.8436
#   Fold 3 Epoch 74 | Train Loss: 0.2778, Acc: 0.9618 | Val Loss: 0.4754, Acc: 0.8471
#   Fold 3 Epoch 75 | Train Loss: 0.2743, Acc: 0.9633 | Val Loss: 0.4850, Acc: 0.8413
#   Fold 3 Epoch 76 | Train Loss: 0.2775, Acc: 0.9623 | Val Loss: 0.4838, Acc: 0.8441
#   Fold 3 Epoch 77 | Train Loss: 0.2746, Acc: 0.9630 | Val Loss: 0.4831, Acc: 0.8510
#     🚨 Fold 3 Early stopping triggered after epoch 77. Best val acc: 0.8516
# ===== Fold 3 Finished in 3550.47s. Best Val Acc: 0.8516 =====
#
# ===== Starting Fold 4/5 =====
# Fold 4: Train batches=1000, Val batches=250
# Fold 4: Initialized new model instance.
#   Fold 4 Epoch  1 | Train Loss: 0.8013, Acc: 0.5449 | Val Loss: 0.6847, Acc: 0.6264
#     🚀 Fold 4 Val Acc improved to 0.6264. Saving model to best_siamese_resnet_fold_4.pth
#   Fold 4 Epoch  2 | Train Loss: 0.6863, Acc: 0.6361 | Val Loss: 0.6101, Acc: 0.6875
#     🚀 Fold 4 Val Acc improved to 0.6875. Saving model to best_siamese_resnet_fold_4.pth
#   Fold 4 Epoch  3 | Train Loss: 0.6356, Acc: 0.6738 | Val Loss: 0.5716, Acc: 0.7290
#     🚀 Fold 4 Val Acc improved to 0.7290. Saving model to best_siamese_resnet_fold_4.pth
#   Fold 4 Epoch  4 | Train Loss: 0.5822, Acc: 0.7243 | Val Loss: 0.5528, Acc: 0.7436
#     🚀 Fold 4 Val Acc improved to 0.7436. Saving model to best_siamese_resnet_fold_4.pth
#   Fold 4 Epoch  5 | Train Loss: 0.5597, Acc: 0.7457 | Val Loss: 0.5318, Acc: 0.7668
#     🚀 Fold 4 Val Acc improved to 0.7668. Saving model to best_siamese_resnet_fold_4.pth
#   Fold 4 Epoch  6 | Train Loss: 0.5438, Acc: 0.7599 | Val Loss: 0.5207, Acc: 0.7779
#     🚀 Fold 4 Val Acc improved to 0.7779. Saving model to best_siamese_resnet_fold_4.pth
#   Fold 4 Epoch  7 | Train Loss: 0.5369, Acc: 0.7653 | Val Loss: 0.5129, Acc: 0.7826
#     🚀 Fold 4 Val Acc improved to 0.7826. Saving model to best_siamese_resnet_fold_4.pth
#   Fold 4 Epoch  8 | Train Loss: 0.5286, Acc: 0.7721 | Val Loss: 0.5182, Acc: 0.7694
#   Fold 4 Epoch  9 | Train Loss: 0.5187, Acc: 0.7788 | Val Loss: 0.4995, Acc: 0.7883
#     🚀 Fold 4 Val Acc improved to 0.7883. Saving model to best_siamese_resnet_fold_4.pth
#   Fold 4 Epoch 10 | Train Loss: 0.5101, Acc: 0.7857 | Val Loss: 0.5032, Acc: 0.7880
#   Fold 4 Epoch 11 | Train Loss: 0.5026, Acc: 0.7929 | Val Loss: 0.4979, Acc: 0.7947
#     🚀 Fold 4 Val Acc improved to 0.7947. Saving model to best_siamese_resnet_fold_4.pth
#   Fold 4 Epoch 12 | Train Loss: 0.4947, Acc: 0.8028 | Val Loss: 0.4770, Acc: 0.8100
#     🚀 Fold 4 Val Acc improved to 0.8100. Saving model to best_siamese_resnet_fold_4.pth
#   Fold 4 Epoch 13 | Train Loss: 0.4867, Acc: 0.8092 | Val Loss: 0.4799, Acc: 0.8029
#   Fold 4 Epoch 14 | Train Loss: 0.4812, Acc: 0.8142 | Val Loss: 0.4742, Acc: 0.8103
#     🚀 Fold 4 Val Acc improved to 0.8103. Saving model to best_siamese_resnet_fold_4.pth
#   Fold 4 Epoch 15 | Train Loss: 0.4738, Acc: 0.8206 | Val Loss: 0.4648, Acc: 0.8120
#     🚀 Fold 4 Val Acc improved to 0.8120. Saving model to best_siamese_resnet_fold_4.pth
#   Fold 4 Epoch 16 | Train Loss: 0.4687, Acc: 0.8219 | Val Loss: 0.4783, Acc: 0.8050
#   Fold 4 Epoch 17 | Train Loss: 0.4645, Acc: 0.8282 | Val Loss: 0.4750, Acc: 0.8099
#   Fold 4 Epoch 18 | Train Loss: 0.4602, Acc: 0.8307 | Val Loss: 0.4684, Acc: 0.8114
#   Fold 4 Epoch 19 | Train Loss: 0.4518, Acc: 0.8351 | Val Loss: 0.4574, Acc: 0.8230
#     🚀 Fold 4 Val Acc improved to 0.8230. Saving model to best_siamese_resnet_fold_4.pth
#   Fold 4 Epoch 20 | Train Loss: 0.4449, Acc: 0.8417 | Val Loss: 0.4675, Acc: 0.8120
#   Fold 4 Epoch 21 | Train Loss: 0.4404, Acc: 0.8467 | Val Loss: 0.4607, Acc: 0.8215
#   Fold 4 Epoch 22 | Train Loss: 0.4340, Acc: 0.8515 | Val Loss: 0.4652, Acc: 0.8133
#   Fold 4 Epoch 23 | Train Loss: 0.4330, Acc: 0.8513 | Val Loss: 0.4598, Acc: 0.8204
#   Fold 4 Epoch 24 | Train Loss: 0.4049, Acc: 0.8731 | Val Loss: 0.4551, Acc: 0.8236
#     🚀 Fold 4 Val Acc improved to 0.8236. Saving model to best_siamese_resnet_fold_4.pth
#   Fold 4 Epoch 25 | Train Loss: 0.3979, Acc: 0.8773 | Val Loss: 0.4422, Acc: 0.8391
#     🚀 Fold 4 Val Acc improved to 0.8391. Saving model to best_siamese_resnet_fold_4.pth
#   Fold 4 Epoch 26 | Train Loss: 0.3929, Acc: 0.8802 | Val Loss: 0.4423, Acc: 0.8350
#   Fold 4 Epoch 27 | Train Loss: 0.3864, Acc: 0.8868 | Val Loss: 0.4482, Acc: 0.8344
#   Fold 4 Epoch 28 | Train Loss: 0.3810, Acc: 0.8903 | Val Loss: 0.4485, Acc: 0.8364
#   Fold 4 Epoch 29 | Train Loss: 0.3757, Acc: 0.8947 | Val Loss: 0.4453, Acc: 0.8357
#   Fold 4 Epoch 30 | Train Loss: 0.3620, Acc: 0.9046 | Val Loss: 0.4468, Acc: 0.8391
#   Fold 4 Epoch 31 | Train Loss: 0.3572, Acc: 0.9086 | Val Loss: 0.4521, Acc: 0.8327
#   Fold 4 Epoch 32 | Train Loss: 0.3500, Acc: 0.9122 | Val Loss: 0.4511, Acc: 0.8377
#   Fold 4 Epoch 33 | Train Loss: 0.3481, Acc: 0.9142 | Val Loss: 0.4490, Acc: 0.8384
#   Fold 4 Epoch 34 | Train Loss: 0.3392, Acc: 0.9198 | Val Loss: 0.4540, Acc: 0.8400
#     🚀 Fold 4 Val Acc improved to 0.8400. Saving model to best_siamese_resnet_fold_4.pth
#   Fold 4 Epoch 35 | Train Loss: 0.3336, Acc: 0.9252 | Val Loss: 0.4595, Acc: 0.8366
#   Fold 4 Epoch 36 | Train Loss: 0.3332, Acc: 0.9250 | Val Loss: 0.4477, Acc: 0.8431
#     🚀 Fold 4 Val Acc improved to 0.8431. Saving model to best_siamese_resnet_fold_4.pth
#   Fold 4 Epoch 37 | Train Loss: 0.3337, Acc: 0.9253 | Val Loss: 0.4494, Acc: 0.8446
#     🚀 Fold 4 Val Acc improved to 0.8446. Saving model to best_siamese_resnet_fold_4.pth
#   Fold 4 Epoch 38 | Train Loss: 0.3302, Acc: 0.9266 | Val Loss: 0.4525, Acc: 0.8450
#     🚀 Fold 4 Val Acc improved to 0.8450. Saving model to best_siamese_resnet_fold_4.pth
#   Fold 4 Epoch 39 | Train Loss: 0.3277, Acc: 0.9286 | Val Loss: 0.4522, Acc: 0.8435
#   Fold 4 Epoch 40 | Train Loss: 0.3266, Acc: 0.9280 | Val Loss: 0.4532, Acc: 0.8433
#   Fold 4 Epoch 41 | Train Loss: 0.3248, Acc: 0.9310 | Val Loss: 0.4544, Acc: 0.8427
#   Fold 4 Epoch 42 | Train Loss: 0.3227, Acc: 0.9327 | Val Loss: 0.4489, Acc: 0.8470
#     🚀 Fold 4 Val Acc improved to 0.8470. Saving model to best_siamese_resnet_fold_4.pth
#   Fold 4 Epoch 43 | Train Loss: 0.3191, Acc: 0.9343 | Val Loss: 0.4484, Acc: 0.8478
#     🚀 Fold 4 Val Acc improved to 0.8478. Saving model to best_siamese_resnet_fold_4.pth
#   Fold 4 Epoch 44 | Train Loss: 0.3198, Acc: 0.9332 | Val Loss: 0.4531, Acc: 0.8468
#   Fold 4 Epoch 45 | Train Loss: 0.3185, Acc: 0.9339 | Val Loss: 0.4545, Acc: 0.8468
#   Fold 4 Epoch 46 | Train Loss: 0.3156, Acc: 0.9372 | Val Loss: 0.4517, Acc: 0.8480
#     🚀 Fold 4 Val Acc improved to 0.8480. Saving model to best_siamese_resnet_fold_4.pth
#   Fold 4 Epoch 47 | Train Loss: 0.3162, Acc: 0.9362 | Val Loss: 0.4623, Acc: 0.8417
#   Fold 4 Epoch 48 | Train Loss: 0.3144, Acc: 0.9379 | Val Loss: 0.4652, Acc: 0.8409
#   Fold 4 Epoch 49 | Train Loss: 0.3118, Acc: 0.9389 | Val Loss: 0.4571, Acc: 0.8433
#   Fold 4 Epoch 50 | Train Loss: 0.3125, Acc: 0.9405 | Val Loss: 0.4583, Acc: 0.8468
#   Fold 4 Epoch 51 | Train Loss: 0.3052, Acc: 0.9443 | Val Loss: 0.4575, Acc: 0.8482
#     🚀 Fold 4 Val Acc improved to 0.8482. Saving model to best_siamese_resnet_fold_4.pth
#   Fold 4 Epoch 52 | Train Loss: 0.3040, Acc: 0.9447 | Val Loss: 0.4594, Acc: 0.8460
#   Fold 4 Epoch 53 | Train Loss: 0.3048, Acc: 0.9441 | Val Loss: 0.4663, Acc: 0.8420
#   Fold 4 Epoch 54 | Train Loss: 0.2995, Acc: 0.9475 | Val Loss: 0.4604, Acc: 0.8480
#   Fold 4 Epoch 55 | Train Loss: 0.3028, Acc: 0.9451 | Val Loss: 0.4651, Acc: 0.8438
#   Fold 4 Epoch 56 | Train Loss: 0.2998, Acc: 0.9471 | Val Loss: 0.4657, Acc: 0.8435
#   Fold 4 Epoch 57 | Train Loss: 0.3018, Acc: 0.9455 | Val Loss: 0.4619, Acc: 0.8481
#   Fold 4 Epoch 58 | Train Loss: 0.2985, Acc: 0.9485 | Val Loss: 0.4635, Acc: 0.8460
#   Fold 4 Epoch 59 | Train Loss: 0.2997, Acc: 0.9477 | Val Loss: 0.4642, Acc: 0.8475
#   Fold 4 Epoch 60 | Train Loss: 0.2965, Acc: 0.9496 | Val Loss: 0.4642, Acc: 0.8475
#   Fold 4 Epoch 61 | Train Loss: 0.2940, Acc: 0.9504 | Val Loss: 0.4673, Acc: 0.8445
#   Fold 4 Epoch 62 | Train Loss: 0.3007, Acc: 0.9476 | Val Loss: 0.4706, Acc: 0.8458
#   Fold 4 Epoch 63 | Train Loss: 0.2968, Acc: 0.9484 | Val Loss: 0.4640, Acc: 0.8481
#   Fold 4 Epoch 64 | Train Loss: 0.2957, Acc: 0.9510 | Val Loss: 0.4692, Acc: 0.8421
#   Fold 4 Epoch 65 | Train Loss: 0.2971, Acc: 0.9488 | Val Loss: 0.4657, Acc: 0.8472
#   Fold 4 Epoch 66 | Train Loss: 0.2957, Acc: 0.9496 | Val Loss: 0.4576, Acc: 0.8472
#   Fold 4 Epoch 67 | Train Loss: 0.2959, Acc: 0.9490 | Val Loss: 0.4696, Acc: 0.8430
#   Fold 4 Epoch 68 | Train Loss: 0.2953, Acc: 0.9508 | Val Loss: 0.4673, Acc: 0.8454
#   Fold 4 Epoch 69 | Train Loss: 0.2946, Acc: 0.9517 | Val Loss: 0.4637, Acc: 0.8480
#   Fold 4 Epoch 70 | Train Loss: 0.2948, Acc: 0.9507 | Val Loss: 0.4611, Acc: 0.8501
#     🚀 Fold 4 Val Acc improved to 0.8501. Saving model to best_siamese_resnet_fold_4.pth
#   Fold 4 Epoch 71 | Train Loss: 0.2917, Acc: 0.9523 | Val Loss: 0.4699, Acc: 0.8451
#   Fold 4 Epoch 72 | Train Loss: 0.2955, Acc: 0.9519 | Val Loss: 0.4707, Acc: 0.8451
#   Fold 4 Epoch 73 | Train Loss: 0.2953, Acc: 0.9510 | Val Loss: 0.4648, Acc: 0.8468
#   Fold 4 Epoch 74 | Train Loss: 0.2970, Acc: 0.9500 | Val Loss: 0.4666, Acc: 0.8475
#   Fold 4 Epoch 75 | Train Loss: 0.2936, Acc: 0.9515 | Val Loss: 0.4682, Acc: 0.8501
#   Fold 4 Epoch 76 | Train Loss: 0.2936, Acc: 0.9517 | Val Loss: 0.4627, Acc: 0.8464
#   Fold 4 Epoch 77 | Train Loss: 0.2915, Acc: 0.9522 | Val Loss: 0.4692, Acc: 0.8465
#   Fold 4 Epoch 78 | Train Loss: 0.2953, Acc: 0.9509 | Val Loss: 0.4587, Acc: 0.8469
#   Fold 4 Epoch 79 | Train Loss: 0.2953, Acc: 0.9516 | Val Loss: 0.4572, Acc: 0.8494
#   Fold 4 Epoch 80 | Train Loss: 0.2930, Acc: 0.9527 | Val Loss: 0.4619, Acc: 0.8509
#     🚀 Fold 4 Val Acc improved to 0.8509. Saving model to best_siamese_resnet_fold_4.pth
# ===== Fold 4 Finished in 3840.66s. Best Val Acc: 0.8509 =====
#
# ===== Starting Fold 5/5 =====
# Fold 5: Train batches=1000, Val batches=250
# Fold 5: Initialized new model instance.
#   Fold 5 Epoch  1 | Train Loss: 0.7900, Acc: 0.5573 | Val Loss: 0.6439, Acc: 0.6409
#     🚀 Fold 5 Val Acc improved to 0.6409. Saving model to best_siamese_resnet_fold_5.pth
#   Fold 5 Epoch  2 | Train Loss: 0.6525, Acc: 0.6539 | Val Loss: 0.5999, Acc: 0.6943
#     🚀 Fold 5 Val Acc improved to 0.6943. Saving model to best_siamese_resnet_fold_5.pth
#   Fold 5 Epoch  3 | Train Loss: 0.5929, Acc: 0.7058 | Val Loss: 0.5652, Acc: 0.7375
#     🚀 Fold 5 Val Acc improved to 0.7375. Saving model to best_siamese_resnet_fold_5.pth
#   Fold 5 Epoch  4 | Train Loss: 0.5665, Acc: 0.7372 | Val Loss: 0.5415, Acc: 0.7575
#     🚀 Fold 5 Val Acc improved to 0.7575. Saving model to best_siamese_resnet_fold_5.pth
#   Fold 5 Epoch  5 | Train Loss: 0.5488, Acc: 0.7520 | Val Loss: 0.5320, Acc: 0.7586
#     🚀 Fold 5 Val Acc improved to 0.7586. Saving model to best_siamese_resnet_fold_5.pth
#   Fold 5 Epoch  6 | Train Loss: 0.5383, Acc: 0.7647 | Val Loss: 0.5260, Acc: 0.7628
#     🚀 Fold 5 Val Acc improved to 0.7628. Saving model to best_siamese_resnet_fold_5.pth
#   Fold 5 Epoch  7 | Train Loss: 0.5274, Acc: 0.7738 | Val Loss: 0.5112, Acc: 0.7823
#     🚀 Fold 5 Val Acc improved to 0.7823. Saving model to best_siamese_resnet_fold_5.pth
#   Fold 5 Epoch  8 | Train Loss: 0.5210, Acc: 0.7815 | Val Loss: 0.4991, Acc: 0.7939
#     🚀 Fold 5 Val Acc improved to 0.7939. Saving model to best_siamese_resnet_fold_5.pth
#   Fold 5 Epoch  9 | Train Loss: 0.5145, Acc: 0.7846 | Val Loss: 0.5013, Acc: 0.7915
#   Fold 5 Epoch 10 | Train Loss: 0.5070, Acc: 0.7915 | Val Loss: 0.4895, Acc: 0.7983
#     🚀 Fold 5 Val Acc improved to 0.7983. Saving model to best_siamese_resnet_fold_5.pth
#   Fold 5 Epoch 11 | Train Loss: 0.4954, Acc: 0.8021 | Val Loss: 0.4874, Acc: 0.7986
#     🚀 Fold 5 Val Acc improved to 0.7986. Saving model to best_siamese_resnet_fold_5.pth
#   Fold 5 Epoch 12 | Train Loss: 0.4940, Acc: 0.8032 | Val Loss: 0.4819, Acc: 0.8020
#     🚀 Fold 5 Val Acc improved to 0.8020. Saving model to best_siamese_resnet_fold_5.pth
#   Fold 5 Epoch 13 | Train Loss: 0.4848, Acc: 0.8114 | Val Loss: 0.4816, Acc: 0.8036
#     🚀 Fold 5 Val Acc improved to 0.8036. Saving model to best_siamese_resnet_fold_5.pth
#   Fold 5 Epoch 14 | Train Loss: 0.4789, Acc: 0.8169 | Val Loss: 0.4732, Acc: 0.8077
#     🚀 Fold 5 Val Acc improved to 0.8077. Saving model to best_siamese_resnet_fold_5.pth
#   Fold 5 Epoch 15 | Train Loss: 0.4717, Acc: 0.8223 | Val Loss: 0.4701, Acc: 0.8071
#   Fold 5 Epoch 16 | Train Loss: 0.4672, Acc: 0.8255 | Val Loss: 0.4641, Acc: 0.8177
#     🚀 Fold 5 Val Acc improved to 0.8177. Saving model to best_siamese_resnet_fold_5.pth
#   Fold 5 Epoch 17 | Train Loss: 0.4640, Acc: 0.8279 | Val Loss: 0.4717, Acc: 0.8119
#   Fold 5 Epoch 18 | Train Loss: 0.4573, Acc: 0.8324 | Val Loss: 0.4586, Acc: 0.8207
#     🚀 Fold 5 Val Acc improved to 0.8207. Saving model to best_siamese_resnet_fold_5.pth
#   Fold 5 Epoch 19 | Train Loss: 0.4491, Acc: 0.8372 | Val Loss: 0.4581, Acc: 0.8266
#     🚀 Fold 5 Val Acc improved to 0.8266. Saving model to best_siamese_resnet_fold_5.pth
#   Fold 5 Epoch 20 | Train Loss: 0.4468, Acc: 0.8417 | Val Loss: 0.4614, Acc: 0.8191
#   Fold 5 Epoch 21 | Train Loss: 0.4383, Acc: 0.8453 | Val Loss: 0.4643, Acc: 0.8213
#   Fold 5 Epoch 22 | Train Loss: 0.4344, Acc: 0.8508 | Val Loss: 0.4657, Acc: 0.8141
#   Fold 5 Epoch 23 | Train Loss: 0.4308, Acc: 0.8532 | Val Loss: 0.4554, Acc: 0.8227
#   Fold 5 Epoch 24 | Train Loss: 0.4034, Acc: 0.8761 | Val Loss: 0.4413, Acc: 0.8373
#     🚀 Fold 5 Val Acc improved to 0.8373. Saving model to best_siamese_resnet_fold_5.pth
#   Fold 5 Epoch 25 | Train Loss: 0.3963, Acc: 0.8799 | Val Loss: 0.4480, Acc: 0.8306
#   Fold 5 Epoch 26 | Train Loss: 0.3900, Acc: 0.8822 | Val Loss: 0.4492, Acc: 0.8296
#   Fold 5 Epoch 27 | Train Loss: 0.3834, Acc: 0.8892 | Val Loss: 0.4447, Acc: 0.8400
#     🚀 Fold 5 Val Acc improved to 0.8400. Saving model to best_siamese_resnet_fold_5.pth
#   Fold 5 Epoch 28 | Train Loss: 0.3801, Acc: 0.8917 | Val Loss: 0.4388, Acc: 0.8396
#   Fold 5 Epoch 29 | Train Loss: 0.3747, Acc: 0.8941 | Val Loss: 0.4432, Acc: 0.8375
#   Fold 5 Epoch 30 | Train Loss: 0.3761, Acc: 0.8936 | Val Loss: 0.4465, Acc: 0.8404
#     🚀 Fold 5 Val Acc improved to 0.8404. Saving model to best_siamese_resnet_fold_5.pth
#   Fold 5 Epoch 31 | Train Loss: 0.3675, Acc: 0.9011 | Val Loss: 0.4446, Acc: 0.8409
#     🚀 Fold 5 Val Acc improved to 0.8409. Saving model to best_siamese_resnet_fold_5.pth
#   Fold 5 Epoch 32 | Train Loss: 0.3646, Acc: 0.9025 | Val Loss: 0.4475, Acc: 0.8419
#     🚀 Fold 5 Val Acc improved to 0.8419. Saving model to best_siamese_resnet_fold_5.pth
#   Fold 5 Epoch 33 | Train Loss: 0.3623, Acc: 0.9051 | Val Loss: 0.4576, Acc: 0.8364
#   Fold 5 Epoch 34 | Train Loss: 0.3563, Acc: 0.9087 | Val Loss: 0.4472, Acc: 0.8393
#   Fold 5 Epoch 35 | Train Loss: 0.3553, Acc: 0.9097 | Val Loss: 0.4515, Acc: 0.8350
#   Fold 5 Epoch 36 | Train Loss: 0.3526, Acc: 0.9127 | Val Loss: 0.4532, Acc: 0.8413
#   Fold 5 Epoch 37 | Train Loss: 0.3349, Acc: 0.9226 | Val Loss: 0.4534, Acc: 0.8419
#   Fold 5 Epoch 38 | Train Loss: 0.3316, Acc: 0.9243 | Val Loss: 0.4528, Acc: 0.8393
#   Fold 5 Epoch 39 | Train Loss: 0.3290, Acc: 0.9267 | Val Loss: 0.4618, Acc: 0.8451
#     🚀 Fold 5 Val Acc improved to 0.8451. Saving model to best_siamese_resnet_fold_5.pth
#   Fold 5 Epoch 40 | Train Loss: 0.3259, Acc: 0.9294 | Val Loss: 0.4507, Acc: 0.8452
#     🚀 Fold 5 Val Acc improved to 0.8452. Saving model to best_siamese_resnet_fold_5.pth
#   Fold 5 Epoch 41 | Train Loss: 0.3228, Acc: 0.9310 | Val Loss: 0.4497, Acc: 0.8470
#     🚀 Fold 5 Val Acc improved to 0.8470. Saving model to best_siamese_resnet_fold_5.pth
#   Fold 5 Epoch 42 | Train Loss: 0.3220, Acc: 0.9303 | Val Loss: 0.4512, Acc: 0.8480
#     🚀 Fold 5 Val Acc improved to 0.8480. Saving model to best_siamese_resnet_fold_5.pth
#   Fold 5 Epoch 43 | Train Loss: 0.3212, Acc: 0.9316 | Val Loss: 0.4517, Acc: 0.8489
#     🚀 Fold 5 Val Acc improved to 0.8489. Saving model to best_siamese_resnet_fold_5.pth
#   Fold 5 Epoch 44 | Train Loss: 0.3146, Acc: 0.9376 | Val Loss: 0.4531, Acc: 0.8478
#   Fold 5 Epoch 45 | Train Loss: 0.3157, Acc: 0.9367 | Val Loss: 0.4588, Acc: 0.8439
#   Fold 5 Epoch 46 | Train Loss: 0.3108, Acc: 0.9386 | Val Loss: 0.4517, Acc: 0.8458
#   Fold 5 Epoch 47 | Train Loss: 0.3115, Acc: 0.9401 | Val Loss: 0.4600, Acc: 0.8444
#   Fold 5 Epoch 48 | Train Loss: 0.3028, Acc: 0.9442 | Val Loss: 0.4599, Acc: 0.8508
#     🚀 Fold 5 Val Acc improved to 0.8508. Saving model to best_siamese_resnet_fold_5.pth
#   Fold 5 Epoch 49 | Train Loss: 0.3032, Acc: 0.9450 | Val Loss: 0.4555, Acc: 0.8531
#     🚀 Fold 5 Val Acc improved to 0.8531. Saving model to best_siamese_resnet_fold_5.pth
#   Fold 5 Epoch 50 | Train Loss: 0.2992, Acc: 0.9487 | Val Loss: 0.4599, Acc: 0.8516
#   Fold 5 Epoch 51 | Train Loss: 0.2962, Acc: 0.9487 | Val Loss: 0.4667, Acc: 0.8471
#   Fold 5 Epoch 52 | Train Loss: 0.2974, Acc: 0.9477 | Val Loss: 0.4578, Acc: 0.8488
#   Fold 5 Epoch 53 | Train Loss: 0.2949, Acc: 0.9497 | Val Loss: 0.4628, Acc: 0.8524
#   Fold 5 Epoch 54 | Train Loss: 0.2936, Acc: 0.9521 | Val Loss: 0.4580, Acc: 0.8510
#   Fold 5 Epoch 55 | Train Loss: 0.2890, Acc: 0.9550 | Val Loss: 0.4737, Acc: 0.8478
#   Fold 5 Epoch 56 | Train Loss: 0.2882, Acc: 0.9536 | Val Loss: 0.4595, Acc: 0.8475
#   Fold 5 Epoch 57 | Train Loss: 0.2866, Acc: 0.9566 | Val Loss: 0.4611, Acc: 0.8475
#   Fold 5 Epoch 58 | Train Loss: 0.2860, Acc: 0.9558 | Val Loss: 0.4637, Acc: 0.8494
#   Fold 5 Epoch 59 | Train Loss: 0.2883, Acc: 0.9544 | Val Loss: 0.4592, Acc: 0.8578
#     🚀 Fold 5 Val Acc improved to 0.8578. Saving model to best_siamese_resnet_fold_5.pth
#   Fold 5 Epoch 60 | Train Loss: 0.2848, Acc: 0.9577 | Val Loss: 0.4649, Acc: 0.8500
#   Fold 5 Epoch 61 | Train Loss: 0.2842, Acc: 0.9568 | Val Loss: 0.4647, Acc: 0.8535
#   Fold 5 Epoch 62 | Train Loss: 0.2850, Acc: 0.9571 | Val Loss: 0.4739, Acc: 0.8498
#   Fold 5 Epoch 63 | Train Loss: 0.2847, Acc: 0.9568 | Val Loss: 0.4703, Acc: 0.8492
#   Fold 5 Epoch 64 | Train Loss: 0.2792, Acc: 0.9603 | Val Loss: 0.4697, Acc: 0.8508
#   Fold 5 Epoch 65 | Train Loss: 0.2824, Acc: 0.9591 | Val Loss: 0.4621, Acc: 0.8551
#   Fold 5 Epoch 66 | Train Loss: 0.2848, Acc: 0.9571 | Val Loss: 0.4648, Acc: 0.8546
#   Fold 5 Epoch 67 | Train Loss: 0.2805, Acc: 0.9607 | Val Loss: 0.4688, Acc: 0.8520
#   Fold 5 Epoch 68 | Train Loss: 0.2795, Acc: 0.9602 | Val Loss: 0.4701, Acc: 0.8489
#   Fold 5 Epoch 69 | Train Loss: 0.2799, Acc: 0.9598 | Val Loss: 0.4631, Acc: 0.8519
#   Fold 5 Epoch 70 | Train Loss: 0.2824, Acc: 0.9583 | Val Loss: 0.4730, Acc: 0.8500
#   Fold 5 Epoch 71 | Train Loss: 0.2803, Acc: 0.9612 | Val Loss: 0.4559, Acc: 0.8590
#     🚀 Fold 5 Val Acc improved to 0.8590. Saving model to best_siamese_resnet_fold_5.pth
#   Fold 5 Epoch 72 | Train Loss: 0.2793, Acc: 0.9603 | Val Loss: 0.4660, Acc: 0.8524
#   Fold 5 Epoch 73 | Train Loss: 0.2802, Acc: 0.9605 | Val Loss: 0.4636, Acc: 0.8566
#   Fold 5 Epoch 74 | Train Loss: 0.2827, Acc: 0.9581 | Val Loss: 0.4667, Acc: 0.8500
#   Fold 5 Epoch 75 | Train Loss: 0.2789, Acc: 0.9609 | Val Loss: 0.4726, Acc: 0.8508
#   Fold 5 Epoch 76 | Train Loss: 0.2806, Acc: 0.9591 | Val Loss: 0.4640, Acc: 0.8541
#   Fold 5 Epoch 77 | Train Loss: 0.2794, Acc: 0.9609 | Val Loss: 0.4772, Acc: 0.8494
#   Fold 5 Epoch 78 | Train Loss: 0.2803, Acc: 0.9603 | Val Loss: 0.4643, Acc: 0.8481
#   Fold 5 Epoch 79 | Train Loss: 0.2803, Acc: 0.9596 | Val Loss: 0.4768, Acc: 0.8484
#   Fold 5 Epoch 80 | Train Loss: 0.2818, Acc: 0.9604 | Val Loss: 0.4625, Acc: 0.8551
# ===== Fold 5 Finished in 3940.78s. Best Val Acc: 0.8590 =====
#
# --- K-Fold Training Finished ---
# Total Training Time: 17888.70s
# Validation accuracies per fold: ['0.8558', '0.8461', '0.8516', '0.8509', '0.8590']
# Average K-Fold Validation Accuracy: 0.8527 (+/- 0.0044)
#
# --- Starting Evaluation Phase (on Validation Set) ---
# '\nprint("\n--- Starting Evaluation Phase (on Fold 1 Model\'s Validation Set) ---")\n\nfold_to_evaluate = 1\neval_model_path = MODEL_SAVE_PATH_TEMPLATE.format(fold=fold_to_evaluate)\n\nif os.path.exists(eval_model_path):\n    eval_model = SiameseNet(pretrained_base=USE_PRETRAINED_BASE).to(DEVICE) # Re-create model structure\n    try:\n        eval_model.load_state_dict(torch.load(eval_model_path, map_location=DEVICE))\n        eval_model.eval() # Set to evaluation mode\n        print(f"Loaded Fold {fold_to_evaluate} model state from {eval_model_path}")\n\n        # We need the validation data specific to Fold 1 again for evaluation\n        # Re-create the split for fold 1 to get val_idx1\n        if \'skf\' in locals() and \'dataset_indices\' in locals() and \'dataset_labels\' in locals():\n            # Get the indices for the fold we want to evaluate\n            temp_train_idx, val_idx_eval = list(skf.split(dataset_indices, dataset_labels))[fold_to_evaluate-1]\n            val_dataset_eval = Subset(full_dataset, val_idx_eval)\n\n            if len(val_dataset_eval) > 0:\n                 val_eval_loader = DataLoader(val_dataset_eval, batch_size=INFERENCE_BATCH_SIZE, shuffle=False, num_workers=os.cpu_count()//2, pin_memory=True)\n                 eval_criterion = nn.CrossEntropyLoss() # Need criterion for validate function\n                 val_eval_loss, val_eval_acc = validate(eval_model, val_eval_loader, eval_criterion, DEVICE)\n                 print(f"Evaluation Accuracy on Fold {fold_to_evaluate}\'s Validation Set: {val_eval_acc:.4f}")\n                 print(f"Evaluation Loss on Fold {fold_to_evaluate}\'s Validation Set:   {val_eval_loss:.4f}")\n            else:\n                 print(f"Could not evaluate Fold {fold_to_evaluate} - validation set empty.")\n        else:\n             print("Cannot re-create validation split for evaluation. Required variables not found.")\n\n    except Exception as e:\n        print(f"Error loading or evaluating Fold {fold_to_evaluate} model: {e}")\nelse:\n    print(f"Skipping evaluation: Model file not found for Fold {fold_to_evaluate} at {eval_model_path}")\n\nprint("\n--- Evaluation Phase Finished ---")\n'

# %% [markdown]
# ## Inference

# %%
print("\nStarting Inference Phase (Ensemble Prediction)")

models_for_inference = []
for fold in range(1, K_FOLDS + 1):
    model_path = MODEL_SAVE_PATH_TEMPLATE.format(fold=fold)
    if os.path.exists(model_path):
        model = SiameseNet(pretrained_base=USE_PRETRAINED_BASE).to(DEVICE)
        try:
            model.load_state_dict(torch.load(model_path, map_location=DEVICE))
            model.eval() # Set to evaluation mode
            models_for_inference.append(model)
            print(f"Loaded model from {model_path} for inference.")
        except Exception as e:
            print(f"Warning: Error loading model {model_path}: {e}. Skipping this model.")
    else:
        print(f"Warning: Model file not found at {model_path}. Skipping this model for ensemble.")

if not models_for_inference:
    print("Cannot perform inference: No trained models loaded.")
else:
    print(f"Loaded {len(models_for_inference)} models for ensemble inference.")

    test_dataset = RPSInferenceDataset(TEST_PKL_PATH)
    if len(test_dataset) > 0:
        test_loader = DataLoader(test_dataset, batch_size=INFERENCE_BATCH_SIZE, shuffle=False, num_workers=os.cpu_count()//2)
        print(f"Test DataLoader created: {len(test_loader)} batches.")

        all_preds_ensemble = []
        all_ids = []
        inference_start_time = time.time()
        with torch.no_grad():
            for im1, im2, ids_batch in test_loader:
                im1, im2 = im1.to(DEVICE), im2.to(DEVICE)

                batch_logits_list = []
                for model in models_for_inference:
                    logits = model(im1, im2)
                    batch_logits_list.append(logits)

                avg_logits = torch.stack(batch_logits_list).mean(dim=0)

                preds = avg_logits.argmax(dim=1).cpu().numpy()

                all_preds_ensemble.append(preds)
                all_ids.extend(ids_batch.numpy() if isinstance(ids_batch, torch.Tensor) else ids_batch)

        inference_duration = time.time() - inference_start_time
        print(f"Ensemble inference completed in {inference_duration:.2f}s")

        if all_preds_ensemble:
             final_preds = np.concatenate(all_preds_ensemble)
        else:
             final_preds = np.array([])
             print("Warning: No predictions were generated.")

        print("\n--- Starting Post-processing & Submission ---")

        if 'final_preds' in locals() and len(final_preds) == len(all_ids) and len(final_preds) > 0 :

            final_labels = np.where(final_preds == 1, 1, -1)
            submission_df = pd.DataFrame({'id': all_ids, 'label': final_labels})

            try:
                submission_df.to_csv(SUBMISSION_CSV_PATH, index=False)
                print(f"Submission file saved successfully to: {SUBMISSION_CSV_PATH}")
                print("\nSubmission file preview:")
                print(submission_df.head())
            except Exception as e:
                print(f"Error saving submission file: {e}")
        elif 'final_preds' in locals():
            print(f"Error: Number of predictions ({len(final_preds)}) does not match number of IDs ({len(all_ids)}). Cannot create submission file.")
        else:
            print("Error: No final predictions available to save.")

    else:
        print("Skipping inference: Test dataset could not be loaded or is empty.")

print("\n--- Notebook Execution Finished ---")
# Out:
# --- Starting Inference Phase (Ensemble Prediction) ---
# Loaded model from best_siamese_resnet_fold_1.pth for inference.
# Loaded model from best_siamese_resnet_fold_2.pth for inference.
# Loaded model from best_siamese_resnet_fold_3.pth for inference.
# Loaded model from best_siamese_resnet_fold_4.pth for inference.
# Loaded model from best_siamese_resnet_fold_5.pth for inference.
# Loaded 5 models for ensemble inference.
# Pickle file 'test.pkl' loaded successfully for inference.
# Attempting to stack 'img1' data for inference...
#   'img1' stacked successfully. Shape: (20000, 24, 24)
# Attempting to stack 'img2' data for inference...
#   'img2' stacked successfully. Shape: (20000, 24, 24)
# Inference dataset initialized successfully from test.pkl: 20000 samples.
# Test DataLoader created: 157 batches.
# Ensemble inference completed in 9.52s
#
# --- Starting Post-processing & Submission ---
# Submission file saved successfully to: submission_siamese_resnet_acc.csv
#
# Submission file preview:
#      id  label
# 0  3386     -1
# 1   962      1
# 2  6965      1
# 3  3746     -1
# 4  7308     -1
#
# --- Notebook Execution Finished ---
